# %%
import

# %%
#Importing Data from Unstructured text file - feedback.txt
feedback = pd.read_table(r"C:\Users\PREM MOTGHARE\Desktop\introduction to aiml by infosys\python\Data\feedback.txt", names = ['Reviews'])
feedback.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Importing Data from Unstructured text file - feedback.txt
# ----> 2 feedback = pd.read_table(r"C:\Users\PREM MOTGHARE\Desktop\introduction to aiml by infosys\python\Data\feedback.txt", names = ['Reviews'])
#       3 feedback.head()
#
# NameError: name 'pd' is not defined
